# %%
file_name="tasks.txt"

def load_tasks():
    try:
        with open(file_name,'r') as file:
            return [task.strip() for task in file.readlines()]
    except FileNotFoundError:
        return []

def store_tasks(tasks):
    with open(file_name,'w')as file:
        for task in tasks:
            file.write(task+'\n')

tasks=load_tasks()

while True:
    print("_____ To Do List _____")
    print("1. Add Task")
    print("2. View Task")
    print("3. Remove task")
    print("4.  Exit")

    choice=int(input("Enter your choice"))

    if choice==1:
        task=input("Enter your Task:")
        tasks.append(task)
        store_tasks(tasks)
        print("Task added successfully")
    elif choice==2:
        if not tasks:
            print("No tasks available to view")
        else:
            print("\n Your tasks")
            for i,task in enumerate(tasks,start=1):
                print(f"{i}.{task}")
    elif choice==3:
        if not tasks:
            print("No task available to remove")
        else:
            print("\n Your Tasks")
            for i,task in enumerate(tasks,start=1):
                print(f"{i}.{task}")
            try:
                index=int(input("Enter task number to remove:"))-1
                removed=tasks.pop(index)
                store_tasks(tasks)
                print(f"{removed} removed successfully")
            except (ValueError,IndexError):
                print("Invalid task number")
    elif choice==4:
        print("Do to list app End")
        break
    else:
        print("Invalid choice,try again")
# Out:
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 1
# Enter your Task: eat
# Task added successfully
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 1
# Enter your Task: dance
# Task added successfully
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 1
# Enter your Task: sleep
# Task added successfully
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 2
#  Your tasks
# 1.eating
# 2.reading
# 3.eat
# 4.dance
# 5.sleep
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 3
#  Your Tasks
# 1.eating
# 2.reading
# 3.eat
# 4.dance
# 5.sleep
# Enter task number to remove: 4
# dance removed successfully
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 2
#  Your tasks
# 1.eating
# 2.reading
# 3.eat
# 4.sleep
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 3
#  Your Tasks
# 1.eating
# 2.reading
# 3.eat
# 4.sleep
# Enter task number to remove: 8
# Invalid task number
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 9
# Invalid choice,try again
# _____ To Do List _____
# 1. Add Task
# 2. View Task
# 3. Remove task
# 4.  Exit
# Enter your choice 4
# Do to list app End
